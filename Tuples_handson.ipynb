# %%
t=(1,2,3)

# %%
my_list=[1,2,3]

# %%
t
# Out:
# (1, 2, 3)

# %%
my_list
# Out:
# [1, 2, 3]

# %%
type(t)
# Out:
# tuple

# %%
type(my_list)
# Out:
# list

# %%
len(t)
# Out:
# 3

# %%
t
# Out:
# (1, 2, 3)

# %%
t = ('one', 2)

# %%
t
# Out:
# ('one', 2)

# %%
t[0]
# Out:
# 'one'

# %%
t[-1]
# Out:
# 2

# %%
t = ('a','a','b')

# %%
t.count('a')
# Out:
# 2

# %%
t.index('a')
# Out:
# 0

# %%
t.index('b')
# Out:
# 2

# %%
t
# Out:
# ('a', 'a', 'b')

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list[0] = 'NEW'

# %%
my_list
# Out:
# ['NEW', 2, 3]

# %%
t[0] = 'NEW'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-93bfe9be1549> in <module>
# ----> 1 t[0] = 'NEW'
#
# TypeError: 'tuple' object does not support item assignment
