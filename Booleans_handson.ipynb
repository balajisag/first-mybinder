# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-724ba28f4a9a> in <module>
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b73d74fcede9> in <module>
# ----> 1 false
#
# NameError: name 'false' is not defined

# %%
1 > 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
b = None

# %%
b

# %%
type(b)
# Out:
# NoneType

# %%
b =
# Out:
#   File "<ipython-input-11-51da195f42cb>", line 1
#     b =
#         ^
# SyntaxError: invalid syntax
