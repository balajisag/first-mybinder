# %%
my_dict = {'key1':'value1', 'key2':'value2'}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
prices_lookup = {'apple':2.99, 'oranges':1.99, 'milk':1.80}

# %%
prices_lookup['apple']
# Out:
# 2.99

# %%
d = {'k1':123, 'k2':[0,1,2], 'k3':{'insidekey':100}}

# %%
d['k2']
# Out:
# [0, 1, 2]

# %%
d['k3']
# Out:
# {'insidekey': 100}

# %%
d['k3']['insidekey']
# Out:
# 100

# %%
d['k2'][2]
# Out:
# 2

# %%
d = {'key1':['a','b','c']}

# %%
d
# Out:
# {'key1': ['a', 'b', 'c']}

# %%
mylist = d['key1']

# %%
mylist
# Out:
# ['a', 'b', 'c']

# %%
letter =mylist[2]

# %%
letter
# Out:
# 'c'

# %%
letter.upper()
# Out:
# 'C'

# %%
d
# Out:
# {'key1': ['a', 'b', 'c']}

# %%
d['key1']
# Out:
# ['a', 'b', 'c']

# %%
d['key1'][2]
# Out:
# 'c'

# %%
d['key1'][2].upper()
# Out:
# 'C'

# %%
d = {'k1':100, 'k2':200}

# %%
d
# Out:
# {'k1': 100, 'k2': 200}

# %%
d['k3']=300

# %%
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d['k1']=400

# %%
d
# Out:
# {'k1': 400, 'k2': 200, 'k3': 300}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values([400, 200, 300])

# %%
d.items()
# Out:
# dict_items([('k1', 400), ('k2', 200), ('k3', 300)])

# %%
d
# Out:
# {'k1': 400, 'k2': 200, 'k3': 300}
