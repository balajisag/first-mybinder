# %%
print('Explore two methods in this: \n.format() method \nf-strings (formatted string literals)')
# Out:
# Explore two methods in this:
# .format() method
# f-strings (formatted string literals)

# %%
print("The syntax is : \n'String here{} then also {}'.format('something1','something2')")
# Out:
# The syntax is :
# 'String here{} then also {}'.format('something1','something2')

# %%
print('This is a string {}'.format('INSERTED'))
# Out:
# This is a string INSERTED

# %%
print('The {} {} {}'.format('fox', 'brown', 'quick'))
# Out:
# The fox brown quick

# %%
print('The {2} {1} {0}'.format('fox', 'brown', 'quick'))
# Out:
# The quick brown fox

# %%
print('The {0} {0} {0}'.format('fox', 'brown', 'quick'))
# Out:
# The fox fox fox

# %%
print('The {q} {b} {f}'.format(f='fox', b='brown', q='quick'))
# Out:
# The quick brown fox

# %%
print('Float formatting follows "{values:with.precision f}"')
# Out:
# Float formatting follows "{values:with.precision f}"

# %%
result = 100/777

# %%
result
# Out:
# 0.1287001287001287

# %%
print("The result was {}".format(result))
# Out:
# The result was 0.1287001287001287

# %%
print("The result was {r}".format(r=result))
# Out:
# The result was 0.1287001287001287

# %%
print("The result was {r:1.3f}".format(r=result))
# Out:
# The result was 0.129

# %%
print("The result was {r:10.3f}".format(r=result))
# Out:
# The result was      0.129

# %%
print("f-string format:")
# Out:
# f-string format:

# %%
name = "Jose"

# %%
print(f'Hello, his name is {name}')
# Out:
# Hello, his name is Jose

# %%
name = "Sam"
age = 3

# %%
print(f'{name} is {age} years old.')
# Out:
# Sam is 3 years old.

# %%
num = 23.45678

# %%
print("Four decimal number is :{0:10.4f}".format(num))
print(f"Four decimal number is :{num:{10}.{6}}")
# Out:
# Four decimal number is :   23.4568
# Four decimal number is :   23.4568

# %%
print("Four decimal number is :{0:10.4f}".format(num))
print(f"Four decimal number is :{num:{10}.{4}}")
# Out:
# Four decimal number is :   23.4568
# Four decimal number is :     23.46

# %%
print("Four decimal number is :{0:10.4f}".format(num))
print(f"Four decimal number is :{num:{10}.{2}}")
# Out:
# Four decimal number is :   23.4568
# Four decimal number is :   2.3e+01

# %%
print("Four decimal number is :{0:10.4f}".format(num))
print(f"Four decimal number is :{num:{10}.{1}}")
# Out:
# Four decimal number is :   23.4568
# Four decimal number is :     2e+01

# %%
print("Four decimal number is :{0:10.4f}".format(num))
print(f"Four decimal number is :{num:{10}.{8}}")
# Out:
# Four decimal number is :   23.4568
# Four decimal number is :  23.45678

# %%
print("Four decimal number is :{0:10.4f}".format(num))
print(f"Four decimal number is :{num:{10}.{10}}")
# Out:
# Four decimal number is :   23.4568
# Four decimal number is :  23.45678
