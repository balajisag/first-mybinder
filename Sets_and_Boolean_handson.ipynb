# %%
myset = set()

# %%
myset
# Out:
# set()

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
mylist = [1,1,1,1,3,3,3,3,2,2,2,2]

# %%
set(mylist)
# Out:
# {1, 2, 3}

# %%
print('Boolean')
# Out:
# Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
1 > 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
b = None

# %%
b
