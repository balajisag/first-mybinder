# %%
if True:
    print('ITS TRUE!')
# Out:
# ITS TRUE!

# %%
if 3>2:
    print('ITS TRUE!')
# Out:
# ITS TRUE!

# %%
hungry = True
if hungry:
    print('ITS TRUE!')
# Out:
# ITS TRUE!

# %%
hungry = False
if hungry:
    print('FEED ME!')

# %%
hungry = False
if hungry:
    print('FEED ME!')
else:
    print("Im not hungry")
# Out:
# Im not hungry

# %%
hungry = True
if hungry:
    print('FEED ME!')
else:
    print("Im not hungry")
# Out:
# FEED ME!

# %%
loc ='Bank'
if loc == 'Auto Shop':
    print("Cars are cool!")
else:
    print("I dont know much.")
# Out:
# I dont know much.

# %%
loc ='Bank'
if loc == 'Auto Shop':
    print("Cars are cool!")
elif loc == 'Bank':
    print("Money is cool!")
    elif loc == 'Store':
        print("Welcome to the stote!")
else:
    print("I dont know much.")
# Out:
#   File "<ipython-input-12-b82a1c187545>", line 6
#     elif loc == 'Store':
#        ^
# SyntaxError: invalid syntax

# %%
loc ='Bank'
if loc == 'Auto Shop':
    print("Cars are cool!")
elif loc == 'Bank':
    print("Money is cool!")
elif loc == 'Store':
        print("Welcome to the stote!")
else:
    print("I dont know much.")
# Out:
# Money is cool!
