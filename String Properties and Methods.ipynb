# %%
print('Immutability')
# Out:
# Immutability

# %%
name = "Sam"

# %%
name[0] = 'P'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-f2d6cf6fa9fa> in <module>
# ----> 1 name[0] = 'P'
#
# TypeError: 'str' object does not support item assignment

# %%
x = 'Hello World!!'

# %%
x.capitalize()
# Out:
# 'Hello world!!'

# %%
x.upper()
# Out:
# 'HELLO WORLD!!'

# %%
x.lower()
# Out:
# 'hello world!!'

# %%
x.split()
# Out:
# ['Hello', 'World!!']

# %%
x.split('l')
# Out:
# ['He', '', 'o Wor', 'd!!']
