# %%
# %%writefile myfile.txt
# Hello this is text file
# this is the second line
# this is the third line
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile = open('whoops_wrongfile.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1b3f109890f5> in <module>
# ----> 1 myfile = open('whoops_wrongfile.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'whoops_wrongfile.txt'

# %%
pwd
# Out:
# '/home/jovyan'

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is text file\nthis is the second line\nthis is the third line\n'

# %% [markdown]
# myfile.readlines()

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is text file\n',
#  'this is the second line\n',
#  'this is the third line\n']

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello this is text file\nthis is the second line\nthis is the third line\n'

# %%
with open('myfile.txt', mode = 'r') as myfile:
    contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is text file\nthis is the second line\nthis is the third line\n'

# %%
with open('myfile.txt', mode = 'w') as myfile:
    contents = myfile.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-17-42956f4a934c> in <module>
#       1 with open('myfile.txt', mode = 'w') as myfile:
# ----> 2     contents = myfile.read()
#
# UnsupportedOperation: not readable

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %%
with open('my_new_file.txt', mode='r') as f:
    print(f.read())

# %%
with open('my_new_file.txt', mode = 'a') as f:
    f.write('FOUR ON FOURTH')

# %%
with open('my_new_file.txt', mode='r') as f:
    print(f.read())

# %%
with open('asdasd.txt', mode = 'w') as f:
    f.write('I CREATED THIS FILE!')

# %%
with open('asdasd.txt', mode='r') as f:
    print(f.read())
