# %%
def My_test_function(name):
    "print a name using this function"
    print("User name is:"+name)

# %%
My_test_function('Jose')
# Out:
# User name is:Jose

# %%
def My_add_function(num1, num2):
    return num1 + num2

# %%
My_add_function(1,1)
# Out:
# 2

# %%
result = My_add_function(1,1)
result
# Out:
# 2
