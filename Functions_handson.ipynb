# %%
def say_hello():
    print("hello")
    print('are')
    print('you')

# %%
say_hello()
# Out:
# hello
# are
# you

# %%
say_hello
# Out:
# <function __main__.say_hello()>

# %%
def say_hello(name):
    print(f'Hello {name}')

# %%
say_hello('Jose')
# Out:
# Hello Jose

# %%
say_hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-faa5fc24272a> in <module>
# ----> 1 say_hello()
#
# TypeError: say_hello() missing 1 required positional argument: 'name'

# %%
def say_hello(name='Default'):
    print(f'Hello {name}')

# %%
say_hello()
# Out:
# Hello Default

# %%
def add_num(num1, num2):
    return num1 + num2

# %%
add_num(10, 20)
# Out:
# 30

# %%
result = add_num(10, 20)

# %%
result
# Out:
# 30

# %%
print(result)
# Out:
# 30

# %%
def sum_numbers(num1, num2):
    if type(num1) == int:
        if type(num2) == int:
            return num1 + num2
    elif type(num1) == str:
        if type(num2) == str:
            return int(num1) + int(num2)

# %%
sum_numbers('10', '20')
# Out:
# 30

# %%
type(result)
# Out:
# int

# %%
test = '123'
type(test)
# Out:
# str

# %%
def check_even_list(num_list):
    for number in num_list:
        if number % 2 == 0:
            return True
        else:
            pass

# %%
check_even_list([1,3,5])

# %%
check_even_list([2,4,6])
# Out:
# True

# %%
check_even_list([1,3,5,2])
# Out:
# True

# %%
def check_even_list(num_list):
    #return if any number is even number in the list
    for number in num_list:
        if number % 2 == 0:
            return True
        else:
            pass
    return False

# %%
check_even_list([1,3,5])
# Out:
# False

# %%
check_even_list([1,2,5])
# Out:
# True

# %%
def check_even_list(num_list):
    #return all the even number in the list
    # place holder variables
    even_number = []
    
    for number in num_list:
        if number % 2 == 0:
            even_number.append(number)
        else:
            pass
    return even_number

# %%
check_even_list([1,2,5])
# Out:
# [2]

# %%
check_even_list([1,3,5])
# Out:
# []

# %%
check_even_list([1,2,5,4])
# Out:
# [2, 4]
